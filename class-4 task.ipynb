# %%
passport=input("Do you have passport(yes/no):")
visa=input("Do you have visa (yes/no):")
ticket=input("Do you have ticket(yes/no):")

if passport=="yes":
    if visa=="yes":
        if ticket=="yes":
            print("You can board the flight.")
        else:
            print(" sorry ticket is required to travel ")
    else:
        print(" sorry Visa is required to travel")
else:
    print("sorry passport is required to travel")
# Out:
# Do you have passport(yes/no): yes
# Do you have visa (yes/no): no
# Do you have ticket(yes/no): yes
#  sorry Visa is required to travel
