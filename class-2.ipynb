# %%
# class-2 operators........
# Arithmatic
a=5
b=7
c=3
# Out:
# enter the number 5
# enter the number 7

# %%
print(a+b)
print(a-b)
print(a*b)
print(a/b)
print(a//b)
print(a%b)
print(a**b)
# Out:
# 12
# -2
# 35
# 0.7142857142857143
# 0
# 5
# 78125

# %%
#Assignment Operator
c+=a
print(c)
# Out:
# 10

# %%
b-=a
print(b)
# Out:
# 2

# %%
c*=a
print(c)
# Out:
# 50

# %%
c//=a
print(c)
# Out:
# 10

# %%
c/=a
print(c)
# Out:
# 2.0

# %%
c**=a
print(c)
# Out:
# 32.0

# %%
c=5
b=3
c&=b
print(c)
# Out:
# 1

# %%
c=5
b=3
c|=b
print(c)
# Out:
# 7

# %%
d=10
e=8
d>>=e
print(d)
# Out:
# 0

# %%
d=10
e=8
d<<=e
print(d)
# Out:
# 2560

# %%
#Comparision Operator
a==b
# Out:
# True

# %%
a!=b
# Out:
# False

# %%
a>b
# Out:
# False

# %%
a<b
# Out:
# False

# %%
a>=b
# Out:
# True

# %%
a<=b
# Out:
# True

# %%
#Identity Operator
a is b
# Out:
# True

# %%
a is not b
# Out:
# False

# %%
#logical operators
a = True
b = False
print(a and b)
# Out:
# False

# %%
a = True
b = False
print(a or b)
# Out:
# True

# %%
a=True
print(not a)
# Out:
# False

# %%
#Membership Operator
name = "vamsi"
print("v" in name)
# Out:
# True

# %%
print("y" not in name )
# Out:
# True
